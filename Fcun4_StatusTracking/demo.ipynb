# %% [markdown]
# ### 1. Student_job_tracking_summary.csv 字段 job_id, job_title, company_name, job_desc, tracking_method, timestamp
# ### 2. Student_application_status.csv 字段 job_id, status_update, timestamp
#
# ----------------------------------------
#
# ##### 初始化（demo中是用户定义）-> 职位信息存入 Student_job_tracking_summary 并在 Student_application_status 中创建 "开始流程跟踪。" 的初始记录
# ##### 输入进度描述：1. xx岗位进入xx流程；2. xx岗位流程终止；
# ##### 输入查询进度

# %%
from status_tracking import agent, config
# Out:
# e:\HKU_MSCS\COMP7607nlp\tracking\.env

# %% [markdown]
# ##### 初始化

# %%
message = "我申请了 Name of company/institution: ONERWAY Position: AI 应用开发实习生 Job Description: 1. 开发内部通用场景的 AI 应用，包括但不限于：基于 RAG 的知识库检索及后端 数据的离线链路，为合规/运营/审核使用的 AI 提效工具等； 2. 负责自研的基于 React 框架下的多 AGENT 交互框架； 3. 整合优化内部已有的 AI 应用，基于公有云搭建公司的 AI 应用生态，建立完整的 架构支持长期的 AI 应用迭代。跟踪方式：手动输入"
response = agent.invoke(
    input={"messages": [("user", message)]},
    config=config
)
# Out:
# [values] {'messages': [HumanMessage(content='我申请了 Name of company/institution: ONERWAY Position: AI 应用开发实习生 Job Description: 1. 开发内部通用场景的 AI 应用，包括但不限于：基于 RAG 的知识库检索及后端 数据的离线链路，为合规/运营/审核使用的 AI 提效工具等； 2. 负责自研的基于 React 框架下的多 AGENT 交互框架； 3. 整合优化内部已有的 AI 应用，基于公有云搭建公司的 AI 应用生态，建立完整的 架构支持长期的 AI 应用迭代。跟踪方式：手动输入', additional_kwargs={}, response_metadata={}, id='819debb9-750b-4745-ad1d-6a316e8c9108')]}
# ...

# %%
print(response['messages'][-1].content)
# Out:
# ✅ **网申流程已成功记录！**
#
# **职位信息：**
# - 公司：ONERWAY
# - 职位：AI 应用开发实习生
# - 跟踪方式：手动输入
#
# **岗位描述要点：**
# - 开发内部AI应用，包括RAG知识库检索、后端数据离线链路
# - 负责基于React的多AGENT交互框架
# - 整合优化现有AI应用，搭建公司AI应用生态
#
# 您的申请信息已保存到系统中。当您收到后续通知（如笔试、面试邀请）时，可以随时告诉我来更新申请状态。

# %% [markdown]
# ##### 输入进度描述

# %%
message = "ONERWAY 的 AI 应用开发实习生 进入了笔试流程，11月12号安排笔试"
response = agent.invoke(
    input={"messages": [("user", message)]},
    config=config
)
# Out:
# [values] {'messages': [HumanMessage(content='我申请了 Name of company/institution: ONERWAY Position: AI 应用开发实习生 Job Description: 1. 开发内部通用场景的 AI 应用，包括但不限于：基于 RAG 的知识库检索及后端 数据的离线链路，为合规/运营/审核使用的 AI 提效工具等； 2. 负责自研的基于 React 框架下的多 AGENT 交互框架； 3. 整合优化内部已有的 AI 应用，基于公有云搭建公司的 AI 应用生态，建立完整的 架构支持长期的 AI 应用迭代。跟踪方式：手动输入', additional_kwargs={}, response_metadata={}, id='819debb9-750b-4745-ad1d-6a316e8c9108'), AIMessage(content='我来帮您记录这个AI应用开发实习生的网申流程。首先让我检查一下这个职位是否已经存在记录。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 1671, 'total_tokens': 1748, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1664}, 'prompt_cache_hit_tokens': 1664, 'prompt_cache_miss_tokens': 7}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '5d14697f-6d63-4ceb-9092-14242f372b0d', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_
# ...

# %%
print(response['messages'][-1].content)
# Out:
# ✅ **申请状态已更新！**
#
# **职位：** ONERWAY - AI 应用开发实习生
# **当前状态：** 笔试流程 - 11月12号安排笔试
#
# 已成功记录您的笔试安排。祝您笔试顺利！如果您收到笔试结果或后续面试通知，请随时告诉我继续更新状态。

# %%
message = "上海阶跃星辰智能科技有限公司的大语言模型预训练算法研究员的面试挂了"
response = agent.invoke(
    input={"messages": [("user", message)]},
    config=config
)
# Out:
# [values] {'messages': [HumanMessage(content='我申请了 Name of company/institution: ONERWAY Position: AI 应用开发实习生 Job Description: 1. 开发内部通用场景的 AI 应用，包括但不限于：基于 RAG 的知识库检索及后端 数据的离线链路，为合规/运营/审核使用的 AI 提效工具等； 2. 负责自研的基于 React 框架下的多 AGENT 交互框架； 3. 整合优化内部已有的 AI 应用，基于公有云搭建公司的 AI 应用生态，建立完整的 架构支持长期的 AI 应用迭代。跟踪方式：手动输入', additional_kwargs={}, response_metadata={}, id='819debb9-750b-4745-ad1d-6a316e8c9108'), AIMessage(content='我来帮您记录这个AI应用开发实习生的网申流程。首先让我检查一下这个职位是否已经存在记录。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 1671, 'total_tokens': 1748, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1664}, 'prompt_cache_hit_tokens': 1664, 'prompt_cache_miss_tokens': 7}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '5d14697f-6d63-4ceb-9092-14242f372b0d', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_
# ...

# %%
print(response['messages'][-1].content)
# Out:
# ✅ **申请状态已更新！**
#
# **职位：** 上海阶跃星辰智能科技有限公司 - 大语言模型预训练算法研究员
# **当前状态：** 面试未通过
#
# 很遗憾听到这个消息，但每一次面试都是宝贵的学习经验。建议您：
# 1. 复盘面试过程，总结经验教训
# 2. 继续投递其他相关岗位
# 3. 保持积极心态，机会还有很多
#
# 如果您需要查询其他申请状态或有新的申请要记录，请随时告诉我。

# %%
message = "广发基金量化研究实习生面试时间改到11月20号上午9点"
response = agent.invoke(
    input={"messages": [("user", message)]},
    config=config
)
# Out:
# [values] {'messages': [HumanMessage(content='我申请了 Name of company/institution: ONERWAY Position: AI 应用开发实习生 Job Description: 1. 开发内部通用场景的 AI 应用，包括但不限于：基于 RAG 的知识库检索及后端 数据的离线链路，为合规/运营/审核使用的 AI 提效工具等； 2. 负责自研的基于 React 框架下的多 AGENT 交互框架； 3. 整合优化内部已有的 AI 应用，基于公有云搭建公司的 AI 应用生态，建立完整的 架构支持长期的 AI 应用迭代。跟踪方式：手动输入', additional_kwargs={}, response_metadata={}, id='819debb9-750b-4745-ad1d-6a316e8c9108'), AIMessage(content='我来帮您记录这个AI应用开发实习生的网申流程。首先让我检查一下这个职位是否已经存在记录。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 1671, 'total_tokens': 1748, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1664}, 'prompt_cache_hit_tokens': 1664, 'prompt_cache_miss_tokens': 7}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '5d14697f-6d63-4ceb-9092-14242f372b0d', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_
# ...

# %%
print(response['messages'][-1].content)
# Out:
# ✅ **申请状态已更新！**
#
# **职位：** 广发基金 - 量化研究实习生
# **当前状态：** 面试安排 - 11月20号上午9点
#
# 已成功记录您的面试时间调整。新的面试时间为**11月20号上午9点**。
#
# 祝您面试顺利！建议您提前做好准备，熟悉量化研究相关知识。如果面试后有结果，请及时告诉我更新状态。

# %% [markdown]
# ##### 输入查询进度

# %%
message = "帮我查一下广发基金的岗位申请流程"
response = agent.invoke(
    input={"messages": [("user", message)]},
    config=config
)
# Out:
# [values] {'messages': [HumanMessage(content='我申请了 Name of company/institution: ONERWAY Position: AI 应用开发实习生 Job Description: 1. 开发内部通用场景的 AI 应用，包括但不限于：基于 RAG 的知识库检索及后端 数据的离线链路，为合规/运营/审核使用的 AI 提效工具等； 2. 负责自研的基于 React 框架下的多 AGENT 交互框架； 3. 整合优化内部已有的 AI 应用，基于公有云搭建公司的 AI 应用生态，建立完整的 架构支持长期的 AI 应用迭代。跟踪方式：手动输入', additional_kwargs={}, response_metadata={}, id='819debb9-750b-4745-ad1d-6a316e8c9108'), AIMessage(content='我来帮您记录这个AI应用开发实习生的网申流程。首先让我检查一下这个职位是否已经存在记录。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 1671, 'total_tokens': 1748, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1664}, 'prompt_cache_hit_tokens': 1664, 'prompt_cache_miss_tokens': 7}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '5d14697f-6d63-4ceb-9092-14242f372b0d', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_
# ...

# %%
print(response['messages'][-1].content)
# Out:
# 📋 **广发基金 - 量化研究实习生申请流程**
#
# **当前申请状态：**
# - 公司：广发基金
# - 职位：量化研究实习生
# - 最新状态：面试安排 - 11月20号上午9点
#
# **申请流程时间线：**
# 1. 开始流程跟踪
# 2. 11月5日17点进行线上笔试
# 3. 面试安排 - 11月20号上午9点
#
# **当前进度：** 已通过笔试，等待11月20日上午9点的面试。
#
# 您的申请进展顺利，已进入面试环节。建议您提前为面试做好充分准备，祝您面试成功！

# %%
message = "帮我查一下所有岗位申请流程"
response = agent.invoke(
    input={"messages": [("user", message)]},
    config=config
)
# Out:
# [values] {'messages': [HumanMessage(content='我申请了 Name of company/institution: ONERWAY Position: AI 应用开发实习生 Job Description: 1. 开发内部通用场景的 AI 应用，包括但不限于：基于 RAG 的知识库检索及后端 数据的离线链路，为合规/运营/审核使用的 AI 提效工具等； 2. 负责自研的基于 React 框架下的多 AGENT 交互框架； 3. 整合优化内部已有的 AI 应用，基于公有云搭建公司的 AI 应用生态，建立完整的 架构支持长期的 AI 应用迭代。跟踪方式：手动输入', additional_kwargs={}, response_metadata={}, id='819debb9-750b-4745-ad1d-6a316e8c9108'), AIMessage(content='我来帮您记录这个AI应用开发实习生的网申流程。首先让我检查一下这个职位是否已经存在记录。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 1671, 'total_tokens': 1748, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1664}, 'prompt_cache_hit_tokens': 1664, 'prompt_cache_miss_tokens': 7}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '5d14697f-6d63-4ceb-9092-14242f372b0d', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_
# ...

# %%
print(response['messages'][-1].content)
# Out:
# 📊 **所有岗位申请流程总览**
#
# **按公司分类的申请状态：**
#
# **1. 国家集成电路创新中心 NICIC**
# - 软件-图像算法工程师 (Intern)
#   - 状态：简历筛选未通过 ❌
#
# **2. 上海阶跃星辰智能科技有限公司**
# - 大语言模型预训练算法研究员
#   - 状态：面试未通过 ❌
# - 语音（多模态）算法研究员
#   - 状态：开始流程跟踪 ⏳
#
# **3. 广发基金**
# - 量化研究实习生
#   - 状态：面试安排 - 11月20号上午9点 ✅
#
# **4. ONERWAY**
# - AI 应用开发实习生
#   - 状态：笔试流程 - 11月12号安排笔试 ✅
#
# **当前申请统计：**
# - 总计申请：5个岗位
# - 进行中：3个岗位
# - 已结束：2个岗位（1个未通过，1个简历筛选未通过）
#
# **近期重要安排：**
# - 11月12日：ONERWAY AI应用开发实习生笔试
# - 11月20日：广发基金量化研究实习生面试
#
# 您的申请分布比较合理，建议继续关注进行中的岗位，并为即将到来的笔试和面试做好充分准备！

# %%
message = "帮我规划一下后续所有笔面试的日程"
response = agent.invoke(
    input={"messages": [("user", message)]},
    config=config
)
# Out:
# [values] {'messages': [HumanMessage(content='我申请了 Name of company/institution: ONERWAY Position: AI 应用开发实习生 Job Description: 1. 开发内部通用场景的 AI 应用，包括但不限于：基于 RAG 的知识库检索及后端 数据的离线链路，为合规/运营/审核使用的 AI 提效工具等； 2. 负责自研的基于 React 框架下的多 AGENT 交互框架； 3. 整合优化内部已有的 AI 应用，基于公有云搭建公司的 AI 应用生态，建立完整的 架构支持长期的 AI 应用迭代。跟踪方式：手动输入', additional_kwargs={}, response_metadata={}, id='819debb9-750b-4745-ad1d-6a316e8c9108'), AIMessage(content='我来帮您记录这个AI应用开发实习生的网申流程。首先让我检查一下这个职位是否已经存在记录。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 1671, 'total_tokens': 1748, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1664}, 'prompt_cache_hit_tokens': 1664, 'prompt_cache_miss_tokens': 7}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_ffc7281d48_prod0820_fp8_kvcache', 'id': '5d14697f-6d63-4ceb-9092-14242f372b0d', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_
# ...

# %%
print(response['messages'][-1].content)
# Out:
# 📅 **后续笔面试日程规划**
#
# 基于您的申请状态，我为您制定了详细的日程规划：
#
# ## 🗓️ **近期重要安排**
#
# ### **11月12日（周二）- ONERWAY AI应用开发实习生笔试**
# **准备重点：**
# - RAG知识库检索系统
# - React框架下的多AGENT交互
# - 后端数据离线链路
# - 公有云AI应用生态搭建
#
# **复习建议：**
# - 复习React框架和AGENT交互原理
# - 准备RAG相关技术问题
# - 了解云服务部署经验
#
# ### **11月20日（周三）- 广发基金量化研究实习生面试**
# **准备重点：**
# - AI技术在金融市场的应用
# - Transformer、GCN等模型在量化分析中的应用
# - 模型评估指标（IC、IR、收益、稳定性）
# - 模型诊断与优化
#
# **复习建议：**
# - 准备金融数据分析案例
# - 复习机器学习模型评估方法
# - 准备量化交易相关知识
#
# ## 📝 **待处理岗位**
#
# ### **上海阶跃星辰智能科技有限公司 - 语音（多模态）算法研究员**
# **当前状态：** 开始流程跟踪
# **建议行动：**
# - 关注后续通知
# - 准备语音合成、多模态算法相关知识
# - 复习TensorFlow/PyTorch框架使用
#
# ## 🎯 **备考策略建议**
#
# ### **技术栈重点：**
# 1. **AI算法方向：** 大语言模型、语音合成、多模态算法
# 2. **开发方向：** React框架、RAG系统、云服务
# 3. **量化方向：** 金融数据分析、模型评估
#
# ### **时间分配建议：**
# - **11月11日前：** 集中准备ONERWAY笔试
# - **11月13-19日：** 准备广发基金面试
# - **日常：** 关注其他岗位进展，准备技术面试通用问题
#
# ## 💡 **注意事项**
# 1. 提前测试设备，确保网络稳定
# 2. 准备个人项目介绍和技术亮点
# 3. 针对不同岗位调整面试策略
# 4. 保持积极心态，合理安排休息
#
# 祝您笔面试顺利！如有新的进展，请及时告诉我更新状态。
